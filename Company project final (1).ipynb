# %%
# Importing necessary libraries
import pandas as pd
import numpy as np

#Loading data
df=pd.read_csv('EV_new.csv')
df
# Out:
#         Identifier           City  Postal Code  Model Year        Make  \
# 0       KL8CL6S05E         Tacoma      98407.0        2014   CHEVROLET
# 1       JTDKARFP0H  Port Townsend      98368.0        2017      TOYOTA
# 2       JHMZC5F34J         Vashon      98070.0        2018       HONDA
# 3       KMHC65LD0K     Ridgefield      98642.0        2019     HYUNDAI
# 4       1N4AZ1CP6J      Bremerton      98337.0        2018      NISSAN
# ...            ...            ...          ...         ...         ...
# 135033  JTDKARFP0H   Port Angeles      98362.0        2017      TOYOTA
# 135034  5YJ3E1EB7L        Seattle      98134.0        2020       TESLA
# 135035  7FCTGAAL4N         Renton      98059.0        2022      RIVIAN
# 135036  WVGGNPE28N     Bellingham      98225.0        2022  VOLKSWAGEN
# 135037  2C4RC1N70L        Seattle      98126.0        2020    CHRYSLER
#
#               Model                   Electric Vehicle Type  \
# ...

# %%
# Displaying the first few rows of the dataframe
df.head()
# Out:
#    Identifier           City  Postal Code  Model Year       Make        Model  \
# 0  KL8CL6S05E         Tacoma      98407.0        2014  CHEVROLET        SPARK
# 1  JTDKARFP0H  Port Townsend      98368.0        2017     TOYOTA  PRIUS PRIME
# 2  JHMZC5F34J         Vashon      98070.0        2018      HONDA      CLARITY
# 3  KMHC65LD0K     Ridgefield      98642.0        2019    HYUNDAI        IONIQ
# 4  1N4AZ1CP6J      Bremerton      98337.0        2018     NISSAN         LEAF
#
#                     Electric Vehicle Type  \
# 0          Battery Electric Vehicle (BEV)
# 1  Plug-in Hybrid Electric Vehicle (PHEV)
# 2  Plug-in Hybrid Electric Vehicle (PHEV)
# 3  Plug-in Hybrid Electric Vehicle (PHEV)
# 4          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible            82.0
# 1             Not eligible due to low battery range            25.0
# ...

# %%
# Displaying the last 5 rows of the dataframe
df.tail()
# Out:
#         Identifier          City  Postal Code  Model Year        Make  \
# 135033  JTDKARFP0H  Port Angeles      98362.0        2017      TOYOTA
# 135034  5YJ3E1EB7L       Seattle      98134.0        2020       TESLA
# 135035  7FCTGAAL4N        Renton      98059.0        2022      RIVIAN
# 135036  WVGGNPE28N    Bellingham      98225.0        2022  VOLKSWAGEN
# 135037  2C4RC1N70L       Seattle      98126.0        2020    CHRYSLER
#
#               Model                   Electric Vehicle Type  \
# 135033  PRIUS PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 135034      MODEL 3          Battery Electric Vehicle (BEV)
# 135035          R1T          Battery Electric Vehicle (BEV)
# 135036         ID.4          Battery Electric Vehicle (BEV)
# 135037     PACIFICA  Plug-in Hybrid Electric Vehicle (PHEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 135033              Not eligible due to low battery range            25.0
# ...

# %%
# Getting information about the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135038 entries, 0 to 135037
# Data columns (total 15 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   Identifier                                         135038 non-null  object
#  1   City                                               135030 non-null  object
#  2   Postal Code                                        135030 non-null  float64
#  3   Model Year                                         135038 non-null  int64
#  4   Make                                               135038 non-null  object
#  5   Model                                              134789 non-null  object
#  6   Electric Vehicle Type                              135038 non-null  object
#  7   Clean Alternative Fuel Vehicle (CAFV) Eligibility  135038 non-null  object
# ...

# %%
#Handling missing values
# Drop rows with any missing values
df = df.dropna()

# Drop columns with any missing values
df = df.dropna(axis=1)

# %%
print(df.isnull().sum())
# Out:
# Identifier                                           0
# City                                                 0
# Postal Code                                          0
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# Legislative District                                 0
# Vehicle ID                                           0
# Vehicle Location                                     0
# Electric Utility                                     0
# 2020 Census Tract                                    0
# dtype: int64

# %%
# Dropping duplicate
df = df.drop_duplicates()

# %%
# Handling outliers
from scipy.stats import zscore

# Select only numeric columns
numeric_columns = df.select_dtypes(include=[np.number]).columns

# Calculate z-scores for numeric columns in the DataFrame
z_scores = zscore(df[numeric_columns])

# Create a mask for outliers (absolute z-score greater than 3)
outliers_mask = (np.abs(z_scores) < 3).all(axis=1)

# Create a new DataFrame without outliers
df_no_outliers = df[outliers_mask]

# %%
from scipy.stats import zscore
z_scores = zscore(df[numeric_columns])
outliers = df[(z_scores > 3)|(z_scores < -3)]
print('Outliers:')
print(outliers)
# Out:
# Outliers:
#        Identifier City  Postal Code  Model Year Make Model  \
# 0             NaN  NaN          NaN         NaN  NaN   NaN
# 1             NaN  NaN          NaN         NaN  NaN   NaN
# 2             NaN  NaN          NaN         NaN  NaN   NaN
# 3             NaN  NaN          NaN         NaN  NaN   NaN
# 4             NaN  NaN          NaN         NaN  NaN   NaN
# ...           ...  ...          ...         ...  ...   ...
# 135033        NaN  NaN          NaN         NaN  NaN   NaN
# 135034        NaN  NaN          NaN         NaN  NaN   NaN
# 135035        NaN  NaN          NaN         NaN  NaN   NaN
# 135036        NaN  NaN          NaN         NaN  NaN   NaN
# 135037        NaN  NaN          NaN         NaN  NaN   NaN
#
#        Electric Vehicle Type  \
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 135033                   NaN
# ...

# %%
# data manipulation
import pandas as pd
import numpy as np
import seaborn as sns
# data viz
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
# Understanding the dataset
df.head()
# Out:
#    Identifier           City  Postal Code  Model Year       Make        Model  \
# 0  KL8CL6S05E         Tacoma      98407.0        2014  CHEVROLET        SPARK
# 1  JTDKARFP0H  Port Townsend      98368.0        2017     TOYOTA  PRIUS PRIME
# 2  JHMZC5F34J         Vashon      98070.0        2018      HONDA      CLARITY
# 3  KMHC65LD0K     Ridgefield      98642.0        2019    HYUNDAI        IONIQ
# 4  1N4AZ1CP6J      Bremerton      98337.0        2018     NISSAN         LEAF
#
#                     Electric Vehicle Type  \
# 0          Battery Electric Vehicle (BEV)
# 1  Plug-in Hybrid Electric Vehicle (PHEV)
# 2  Plug-in Hybrid Electric Vehicle (PHEV)
# 3  Plug-in Hybrid Electric Vehicle (PHEV)
# 4          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible            82.0
# 1             Not eligible due to low battery range            25.0
# ...

# %%
df.tail()
# Out:
#         Identifier          City  Postal Code  Model Year        Make  \
# 135033  JTDKARFP0H  Port Angeles      98362.0        2017      TOYOTA
# 135034  5YJ3E1EB7L       Seattle      98134.0        2020       TESLA
# 135035  7FCTGAAL4N        Renton      98059.0        2022      RIVIAN
# 135036  WVGGNPE28N    Bellingham      98225.0        2022  VOLKSWAGEN
# 135037  2C4RC1N70L       Seattle      98126.0        2020    CHRYSLER
#
#               Model                   Electric Vehicle Type  \
# 135033  PRIUS PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 135034      MODEL 3          Battery Electric Vehicle (BEV)
# 135035          R1T          Battery Electric Vehicle (BEV)
# 135036         ID.4          Battery Electric Vehicle (BEV)
# 135037     PACIFICA  Plug-in Hybrid Electric Vehicle (PHEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 135033              Not eligible due to low battery range            25.0
# ...

# %%
df.shape
# Out:
# (134474, 15)

# %%
df.describe()
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  134474.000000  134474.000000   134474.000000  134474.000000
# mean    98259.228520    2019.657250       74.730208   81015.173004
# std       303.069045       3.001443       98.776037   23748.891680
# min     98001.000000    1997.000000        0.000000   26455.735798
# 25%     98052.000000    2018.000000        0.000000   63713.207686
# 50%     98122.000000    2021.000000       21.000000   76983.777737
# 75%     98370.000000    2022.000000      150.000000  114632.706686
# max     99403.000000    2024.000000      337.000000  845000.000000
#
#        Legislative District    Vehicle ID  2020 Census Tract
# count         134474.000000  1.344740e+05       1.344740e+05
# mean              29.499911  2.063218e+08       5.303964e+10
# std               14.786294  8.590842e+07       1.617660e+07
# min                1.000000  4.385000e+03       5.300195e+10
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 134474 entries, 0 to 135037
# Data columns (total 15 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   Identifier                                         134474 non-null  object
#  1   City                                               134474 non-null  object
#  2   Postal Code                                        134474 non-null  float64
#  3   Model Year                                         134474 non-null  int64
#  4   Make                                               134474 non-null  object
#  5   Model                                              134474 non-null  object
#  6   Electric Vehicle Type                              134474 non-null  object
#  7   Clean Alternative Fuel Vehicle (CAFV) Eligibility  134474 non-null  object
# ...

# %%
# Numerical features in the column
numerical_feature_columns = list(df._get_numeric_data().columns)
numerical_feature_columns
# Out:
# ['Postal Code',
#  'Model Year',
#  'Electric Range',
#  'Base MSRP',
#  'Legislative District',
#  'Vehicle ID',
#  '2020 Census Tract']

# %%
# Categorical features in the column
categorical_feature_columns = list(set(df.columns) - set(df._get_numeric_data().columns))
categorical_feature_columns
# Out:
# ['Identifier',
#  'Make',
#  'Model',
#  'Electric Utility',
#  'Vehicle Location',
#  'Electric Vehicle Type',
#  'City',
#  'Clean Alternative Fuel Vehicle (CAFV) Eligibility']

# %%
df.nunique()
# Out:
# Identifier                                             9017
# City                                                    454
# Postal Code                                             530
# Model Year                                               22
# Make                                                     36
# Model                                                   125
# Electric Vehicle Type                                     2
# Clean Alternative Fuel Vehicle (CAFV) Eligibility         3
# Electric Range                                          102
# Base MSRP                                               376
# Legislative District                                     49
# Vehicle ID                                           134474
# Vehicle Location                                        530
# Electric Utility                                         75
# 2020 Census Tract                                      1765
# dtype: int64

# %%
# Countplot for 'Clean Alternative Fuel Vehicle (CAFV) Eligibility'
plt.figure(figsize=(14, 8))
sns.countplot(x='Clean Alternative Fuel Vehicle (CAFV) Eligibility', data=df)
plt.title('Clean Alternative Fuel Vehicle Eligibility')
plt.show()

# %% [markdown]
# The higher count of 'Battery Electric Vehicle (BEV)' suggests a notable preference or prevalence of fully electric vehicles in the dataset. This could be indicative of a growing interest in all-electric models among consumers. On the other hand, the lower count of 'Plug-in Hybrid Electric Vehicle (PHEV)' implies a comparatively lesser representation of plug-in hybrid models.

# %%
# Scatter plot for 'Electric Range' vs. 'Base MSRP' 
plt.figure(figsize=(16, 8))
sns.scatterplot(x='Electric Range', y='Base MSRP', data=df)
plt.title('Electric Range VS Base MSRP')
plt.show()

# %% [markdown]
# In the scatter plot illustrating the relationship between 'Electric Range' and 'Base MSRP,' we observe an interesting distribution of data points. The majority of points are horizontally clustered together, suggesting that, for the most part, there is not a clear linear correlation between electric range and base manufacturer's suggested retail price (MSRP). However, there is one distinct point positioned higher up on the plot, indicating a deviation from the general clustering.

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Electric Vehicle Type', data=df)
plt.xticks(rotation=45)
plt.title('Distribution of Electric Vehicle Types')
plt.show()

# %% [markdown]
# The higher count of 'Battery Electric Vehicle (BEV)' suggests a notable preference or prevalence of fully electric vehicles in the dataset. This could be indicative of a growing interest in all-electric models among consumers. On the other hand, the lower count of 'Plug-in Hybrid Electric Vehicle (PHEV)' implies a comparatively lesser representation of plug-in hybrid models.

# %%
# Countplot for popular makes
plt.figure(figsize=(12, 6))
sns.countplot(x='Make', data=df, order=df['Make'].value_counts().index[:10])
plt.xticks(rotation=45)
plt.title('Popular makes (Top 10)')
plt.show()

# %% [markdown]
# There is a clear hierarchy in terms of counts, with 'Tesla' being the most prevalent, followed by 'Nissan,' 'Chevrolet,' 'Ford,' 'BMW,' 'Kia,' 'Toyota,' 'Volkswagen,' 'Volvo,' and 'Audi' in descending order. The overwhelming count of 'Tesla' vehicles indicates a significant dominance of Tesla electric models in the dataset, showcasing Tesla's strong presence in the electric vehicle market. This ranking provides insights into the relative popularity of different electric vehicle manufacturers and models in our dataset.

# %%
# Countplot for popular models
plt.figure(figsize=(12, 6))
sns.countplot(x='Model', data=df, order=df['Model'].value_counts().index[:10])
plt.xticks(rotation=45)
plt.title('Popular Models (Top 10)')
plt.show()

# %% [markdown]
# A distinctive pattern emerges with 'Model 3' leading as the most prevalent model, closely followed by 'Model Y' in the second position. However, a noteworthy observation is the relatively small gap in counts between the most popular and second most popular model. The landscape shifts significantly from the second position onward, with a substantial gap between 'Model Y' and the third most popular model, 'Leaf.' This pattern suggests a concentrated preference for 'Model 3' and 'Model Y' over other models, creating a tiered structure in popularity.

# %%
# Geographic Distribution of EV Registrations (Cities, Legislative Districts)
# Countplot for cities
plt.figure(figsize=(12, 6))
sns.countplot(x='City', data=df, order=df['City'].value_counts().index[:10])
plt.xticks(rotation=45)
plt.title('Distribution of EV registrations among the cities')
plt.show()

# %% [markdown]
# In the count plot visualizing the distribution of Electric Vehicle (EV) registrations among cities, the focus is on the top 10 cities with the highest EV registrations. Within this subset, Seattle stands out prominently with the highest count, showcasing its significant dominance in EV adoption. A striking feature is the substantial gap between Seattle and the second-highest city, which is Bellevue. Following Bellevue, there is a relatively consistent distribution of EV registrations among the top 10 cities, with Redmond, Vancouver, Kirkland, Bothell, Sammamish, Renton, Olympia, and Tacoma forming the subsequent ranks. This hierarchical pattern suggests varying levels of EV adoption across these top 10 cities, with Seattle leading by a considerable margin.
# To gain deeper insights, it would be beneficial to explore the specific policies, incentives, or infrastructure developments that contribute to the pronounced EV adoption in Seattle within the top 10 cities. Investigating the factors that bridge or widen the gap between Seattle and other cities, such as Bellevue, within this subset could inform strategies to promote electric vehicle adoption in different urban contexts. Additionally, analyzing demographic and economic factors in each of the top 10 cities may reveal correlations with EV adoption patterns.

# %%
# Countplot for legislative districts
plt.figure(figsize=(12, 6))
sns.countplot(x='Legislative District', data=df, order=df['Legislative District'].value_counts().index[:10])
plt.xticks(rotation=45)
plt.title('Distribution of EV registrations among the Legistrative districts')
plt.show()

# %% [markdown]
# There is a relatively balanced landscape with a modest gap between the counts. The top legislative districts with the highest EV registrations are 41.0, 45.0, and 48.0, showcasing a consistent level of adoption across these districts. Subsequent districts, including 36.0, 1.0, 5.0, 46.0, 43.0, 11.0, and 37.0, follow in descending order, with a gradual decline in counts. This pattern suggests a fairly even distribution of EV registrations across the top 10 legislative districts, with no pronounced outliers.

# %%
# Bar graph for average Electric Range by Electric Vehicle Type
plt.figure(figsize=(12, 8))
sns.barplot(x='Electric Vehicle Type', y='Electric Range', data=df, estimator=np.mean, ci=None, palette='muted')
plt.xticks(rotation=45)
plt.title('Average Electric Range by electric vehicle type')
plt.show()
# Out:
# /tmp/ipykernel_168/2529691077.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Electric Vehicle Type', y='Electric Range', data=df, estimator=np.mean, ci=None, palette='muted')

# %% [markdown]
# A clear distinction emerges, revealing that Battery Electric Vehicles (BEV) exhibit the highest average electric range among the vehicle types. BEVs rely solely on electric power, providing users with extended electric-only driving capabilities. In contrast, Plug-in Hybrid Electric Vehicles (PHEV) display a moderately lower average electric range, reflecting their dual power sources, which combine electricity and traditional fuel. These findings underscore the inherent trade-offs and benefits associated with each electric vehicle type, with BEVs prioritizing extended electric range and PHEVs offering a balance between electric and traditional fuel options.

# %%
# Identify the top 5 makes
top_makes = df['Make'].value_counts().head(5).index

# Filter the dataset for the top 5 makes
df_top_makes = df[df['Make'].isin(top_makes)]

# Get the top 5 models for each of the top 5 makes
top_models_by_make = df_top_makes.groupby('Make')['Model'].value_counts().groupby('Make').head(5).reset_index(name='Count')

# Bar plot for the top 5 models within each of the top 5 makes
plt.figure(figsize=(18, 10))
sns.barplot(x='Make', y='Count', hue='Model', data=top_models_by_make, palette='Set1')
plt.xticks(rotation=45)
plt.legend(loc='upper right', bbox_to_anchor=(1.15, 1))
plt.title('Top 5 models for the top 5 makes')
plt.show()

# %%
# Identify the top 5 models
top_models = df['Model'].value_counts().head(5).index

# Filter the dataset for the top 5 models
df_top_models = df[df['Model'].isin(top_models)]

# Get the top 5 makes for each of the top 5 models
top_makes_by_model = df_top_models.groupby('Model')['Make'].value_counts().groupby('Model').head(5).reset_index(name='Count')

# Bar plot for the top 5 makes within each of the top 5 models
plt.figure(figsize=(18, 10))
sns.barplot(x='Model', y='Count', hue='Make', data=top_makes_by_model, palette='Set1')
plt.xticks(rotation=45)
plt.legend(loc='upper right', bbox_to_anchor=(1.15, 1))
plt.title('Top 5 makes for the top 5 models')
plt.show()

# %%
# Trends in EV registrations over the years
plt.figure(figsize=(12, 6))
sns.lineplot(x='Model Year', y='Base MSRP', data=df, estimator='count', ci=None)
plt.title('Trends in EV Registrations Over the Years')
plt.xlabel('Model Year')
plt.ylabel('Number of Registrations')
plt.show()
# Out:
# /tmp/ipykernel_168/3077355659.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='Model Year', y='Base MSRP', data=df, estimator='count', ci=None)

# %% [markdown]
# In tracing the trends in Electric Vehicle (EV) registrations over the years, a distinctive pattern unfolds, revealing the evolution of EV adoption. Between 2000 and 2010, EV registrations were virtually nonexistent, indicating a nascent phase in the adoption of electric vehicles. A gradual rise commences from 2010, with a substantial uptick between 2015 and 2020, signifying a significant acceleration in EV registrations. The year 2021 experiences a slight dip, followed by a notable resurgence in EV registrations, reaching a peak in the current period. This observed trajectory underscores a transformative shift in consumer attitudes and market dynamics, with a notable surge in EV adoption in recent years.

# %%
# Trends in Electric range over the years
plt.figure(figsize=(12, 6))
sns.lineplot(x='Model Year', y='Electric Range', data=df, ci=None)
plt.title('Trends in Electric Range Over the Years')
plt.xlabel('Model Year')
plt.ylabel('Electric Range')
plt.show()
# Out:
# /tmp/ipykernel_168/1269644645.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='Model Year', y='Electric Range', data=df, ci=None)

# %% [markdown]
# In examining the trends in Electric Range over the years, a discernible evolution unfolds, providing insights into the advancements in electric vehicle technology. The electric range has been on a continuous upward trajectory since before 2000, reflecting a persistent effort to enhance the driving capabilities of electric vehicles. Notably, the electric range reached its peak twice between 2005 and 2010, marking significant milestones in the development of electric vehicle technology. However, a drastic drop occurred in 2011, suggesting potential challenges or shifts in technological focus. Subsequently, the electric range slowly increased over the years, culminating in a peak in 2020. This nuanced timeline reveals the dynamic nature of electric vehicle capabilities and highlights pivotal moments in the quest for extended electric ranges.

# %%
#Trends in Electric Range by Vehicle Type Over the Years
plt.figure(figsize=(14, 8))
sns.lineplot(x='Model Year', y='Electric Range', hue='Electric Vehicle Type', data=df, ci=None)
plt.title('Trends in Electric Range by Vehicle Type Over the Years')
plt.xlabel('Model Year')
plt.ylabel('Electric Range')
plt.legend(loc='upper right', bbox_to_anchor=(1.15, 1))
plt.show()
# Out:
# /tmp/ipykernel_168/168171481.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='Model Year', y='Electric Range', hue='Electric Vehicle Type', data=df, ci=None)

# %% [markdown]
# In analyzing the trends in Electric Range by Vehicle Type over the years, distinct patterns emerge for Battery Electric Vehicles (BEVs) and Plug-in Hybrid Electric Vehicles (PHEVs). For BEVs, there has been a consistent upward trajectory in electric range, indicating a commitment to enhancing the capabilities of fully electric vehicles. Notably, BEVs experienced peaks in electric range in both 2010 and 2021, showcasing significant advancements in technology. While there was a temporary drop in 2010, the subsequent upward trend suggests successful adaptations and continuous improvements. On the other hand, PHEVs exhibit a more modest increase in electric range over the years, reflecting a gradual progression in the dual capabilities of electric and traditional fuel sources.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select only numeric columns for correlation matrix
numeric_columns = df.select_dtypes(include=['number'])
correlation_matrix = numeric_columns.corr()

# Heatmap for correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
from scipy.stats import ttest_ind

# Hypothesis Testing: Compare Base MSRP between Electric Vehicle Types
ev_types = df['Electric Vehicle Type'].unique()
for ev_type in ev_types:
    subset = df[df['Electric Vehicle Type'] == ev_type]
    print(f'T-Test for {ev_type} vs. Others:')
    stat, p_value = ttest_ind(subset['Base MSRP'], df[df['Electric Vehicle Type'] != ev_type]['Base MSRP'])
    print(f'T-Statistic: {stat}, p-Value: {p_value}\n')
# Out:
# T-Test for Battery Electric Vehicle (BEV) vs. Others:
# T-Statistic: 215.45042393856397, p-Value: 0.0
#
# T-Test for Plug-in Hybrid Electric Vehicle (PHEV) vs. Others:
# T-Statistic: -215.45042393856397, p-Value: 0.0

# %% [markdown]
# The extremely high positive t-statistic indicates that the mean Base MSRP for Battery Electric Vehicles (BEV) is significantly higher than the mean Base MSRP for the combined group of other electric vehicle types.
# The p-value of 0.0 suggests strong statistical evidence against the null hypothesis. It essentially means that the observed difference in Base MSRP between BEV and others is not due to random chance but is a real and significant difference.
#
# The extremely high negative t-statistic indicates that the mean Base MSRP for Plug-in Hybrid Electric Vehicles (PHEV) is significantly lower than the mean Base MSRP for the combined group of other electric vehicle types.
# Similar to BEV, the p-value of 0.0 provides strong statistical evidence against the null hypothesis. It indicates that the observed difference in Base MSRP between PHEV and others is not random but is a real and significant difference.

# %%
# Box plot for Base MSRP
plt.figure(figsize=(12, 50))
sns.boxplot(x=df['Electric Vehicle Type'], y=df['Base MSRP'])
plt.title('Box Plot of Base MSRP by Electric Vehicle Type')
plt.xlabel('Electric Vehicle Type')
plt.ylabel('Base MSRP')
plt.show()

# %%
df['Electric Range'].hist()
plt.title('Electric Range Distribution')
plt.xlabel('Electric Range')
plt.ylabel('Frequency')
plt.show()

# %%
# Pie Chart
df['Electric Vehicle Type'].value_counts().plot.pie(autopct='%1.1f%%')
plt.title('Distribution of Electric Vehicle Types')
plt.show()

# %% [markdown]
# The pie chart provides a visual representation of the distribution of Electric Vehicle types in the dataset.
# Battery Electric Vehicles (BEVs) dominate the dataset, constituting a significant majority at 76.9%.
# The prevalence of BEVs suggests a strong presence of fully electric vehicles, indicating a potential trend towards cleaner and more sustainable transportation solutions.
# Plug-in Hybrid Electric Vehicles (PHEVs) make up the remaining 23.1%, representing a smaller but still notable portion of the dataset.
# The presence of both BEVs and PHEVs in the dataset underscores the diversity of electric vehicle options available, catering to different consumer preferences and needs

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(12, 6))

# Aggregate data by Electric Vehicle Type and calculate the mean Base MSRP
agg_df = df.groupby('Electric Vehicle Type')['Base MSRP'].mean().reset_index()

# Create a line plot
sns.lineplot(x='Electric Vehicle Type', y='Base MSRP', data=agg_df, marker='o')

# Add labels and title
plt.xlabel('Electric Vehicle Type')
plt.ylabel('Average Base MSRP')
plt.title('Average Base MSRP by Electric Vehicle Type')

# Show the plot
plt.show()

# %% [markdown]
# The line chart depicts the average Base MSRP trend for Battery Electric Vehicles (BEVs) and Plug-in Hybrid Electric Vehicles (PHEVs).
# Over the data points, BEVs consistently exhibit a higher average Base MSRP compared to PHEVs.
# This suggests that, on average, Battery Electric Vehicles tend to be priced higher than Plug-in Hybrid Electric Vehicles in the dataset.
# The observed pricing difference may be influenced by factors such as the range, features, and technology associated with each type of electric vehicle.
# Consumers seeking a more affordable option may find that Plug-in Hybrid Electric Vehicles offer a lower average Base MSRP compared to their fully electric counterparts.

# %%
# bar plot for Base MSRP across all models
plt.figure(figsize=(12, 18))
sns.barplot(x='Base MSRP', y='Model', data=df, palette='viridis', orient='h')
plt.xlabel('Base MSRP')
plt.ylabel('Model')
plt.title('Base MSRP Across All Models (Horizontal Bar Plot)')
plt.show()

# %%
# bar plot for Base MSRP among Makes
plt.figure(figsize=(12, 6))
sns.barplot(x='Make', y='Base MSRP', data=df, palette='viridis')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.xlabel('Make')
plt.ylabel('Base MSRP')
plt.title('Base MSRP Among Makess')
plt.show()

# %% [markdown]
# ## Task -Feature Engineering, Model Building, and Fine-Tuning

# %% [markdown]
# ### Analyzing Feature Relevance and Importance:

# %%
# Correlation matrix
correlation_matrix = df.corr()

# Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.show()
# Out:
# /tmp/ipykernel_168/2229832161.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %% [markdown]
# ### Feature Selection and Engineering

# %%
# Drop irrelevant columns
columns_to_drop = ['Identifier', 'Vehicle ID']
df = df.drop(columns_to_drop, axis=1)

# %%
df = pd.get_dummies(df, columns=['City', 'Make', 'Model', 'Electric Vehicle Type',
                                 'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 
                                 'Vehicle Location', 'Electric Utility'])

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import PolynomialFeatures

# %%
# Performing feature selection using random forest
X = df.drop('Base MSRP', axis=1)
y = df['Base MSRP']
selector = SelectFromModel(RandomForestRegressor())
selector.fit(X, y)
selected_features = X.columns[selector.get_support()]

# %%
# Engineer new features
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X[selected_features])

# %% [markdown]
# ### Model Building and Fine-Tuning

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV

# %%
# Splitting the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_poly, y, test_size=0.2, random_state=42)

# %%
# Building the regression model
model = RandomForestRegressor()
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
# Fine-tuning the model
param_grid = {'n_estimators': [100, 200, 300], 'max_depth': [10, 20, 30]}

# %%
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='neg_mean_squared_error')

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [10, 20, 30],
#                          'n_estimators': [100, 200, 300]},
#              scoring='neg_mean_squared_error')

# %%
best_model = grid_search.best_estimator_

# %%
# Evaluate the final model
y_pred = best_model.predict(X_test)
final_mse = mean_squared_error(y_test, y_pred)

# %%
# Calculating evaluation metrics
mse_test = mean_squared_error(y_test, y_pred)
rmse_test = np.sqrt(mse_test)
r_squared_test = best_model.score(X_test, y_test)

print("Mean Squared Error (MSE) on Test Set:", mse_test)
print("Root Mean Squared Error (RMSE) on Test Set:", rmse_test)
print("R-squared on Test Set:", r_squared_test)
# Out:
# Mean Squared Error (MSE) on Test Set: 3501339.0651020813
# Root Mean Squared Error (RMSE) on Test Set: 1871.1865393653518
# R-squared on Test Set: 0.9937831244560139

# %% [markdown]
# #### The model is performing well on the test set, with a low MSE and RMSE, and a high R-squared value. These results indicate that the model is explaining a significant portion of the variance in the target variable (Base MSRP).

# %% [markdown]
# ### Insights:
# Electric Range:
#
# The feature "Electric Range" has a relatively high importance, suggesting that the range of the electric vehicle significantly influences the retail price. Vehicles with longer electric ranges may command higher prices.
# Make and Model:
#
# The importance of features related to "Make" and "Model" indicates that the brand and specific model of the vehicle contribute to pricing. Certain brands or models may have higher perceived value, leading to price variations.
# Model Year:
#
# The "Model Year" is an important factor, implying that newer models may have higher retail prices. Stay updated with the latest vehicle models and technology to maintain competitiveness.
# Electric Vehicle Type:
#
# The type of electric vehicle ("Battery Electric Vehicle (BEV)") is significant, suggesting that the drivetrain technology plays a role in pricing. Understanding customer preferences for different electric vehicle types is crucial.
# Clean Alternative Fuel Vehicle Eligibility:
#
# The eligibility for clean alternative fuel vehicles has an impact. Explore the market demand for eligible vehicles and adjust pricing strategies accordingly.
# Recommendations:
# Emphasize Electric Range:
#
# Highlight the electric range of your electric vehicles in marketing materials. Consider offering models with extended electric ranges to cater to customers who prioritize longer electric driving distances.
# Leverage Brand and Model Reputation:
#
# Capitalize on the positive reputation of high-value brands and popular models. Consider strategic marketing efforts to emphasize the unique features and benefits of your brand and models.
# Stay Competitive with Model Year Updates:
#
# Regularly update vehicle models to stay competitive with the latest technology and design trends. Highlight improvements and innovations in newer model years to justify pricing.
# Diversify Electric Vehicle Types:
#
# If feasible, consider offering a diverse range of electric vehicle types, such as plug-in hybrids or other alternative fuel options. This can cater to different customer preferences and expand market reach.
# Explore Incentives for Eligible Vehicles:
#
# Explore incentives or promotions for vehicles eligible for clean alternative fuel programs. This can attract environmentally conscious customers and enhance the perceived value of your vehicles.
# Monitor Market Trends:
#
# Stay informed about market trends and competitor pricing strategies. Continuous monitoring allows for timely adjustments to maintain competitiveness and meet changing consumer preferences.
